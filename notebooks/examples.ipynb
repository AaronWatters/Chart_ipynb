# %%
from chart_ipynb import chart_framework

# %%
chart_framework.example_donut()
# Out:
# ChartSuperClass(status='deferring flush until render')

# %%
from chart_ipynb import doughnut

# %%
x = doughnut.example()
#x.debugging_display()
x

# %%
a = x.pixels_array()

# %%
a.shape, a.max(), a.min()
# Out:
# ((600, 1200, 4), 255, 0)

# %%
y = x.embed_image()
# Out:
# <PIL.Image.Image image mode=RGBA size=1200x600 at 0x7FC130427BA8>

# %%
x.element.hide()
# Out:
# ['method', <class 'jp_proxy_widget.proxy_widget.CommandMaker'>::140467714587952, 'hide']

# %%
x.save_image("donut.png")

# %% [markdown]
# # Image saved below:
#
# <img src="donut.png" width="300">
